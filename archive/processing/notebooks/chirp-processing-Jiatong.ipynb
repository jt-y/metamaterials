# %%
import os
import pickle
import glob
import skimage
import skimage.transform
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm

import sys

sys.path.append('../functions')

import chirp_functions as proc
# %matplotlib inline

# %%
## STEP 1: PREPROCESS DATA
proc.preprocess_chirp(data_dir = '../../data/kagome-01.21.2022-corner/raw/gamma-K', 
                       frequencies = np.linspace(1000, 20000, 951), 
                       targetfile = '../../data/kagome-01.21.2022-corner/preprocessed/', 
                       title = 'scppos_', setno = 0)
# Out:
# Found 19 records
# Preprocessing complete!

# %%
#correct phase

from tqdm import tqdm


freq_num = 500
freq_min = 2000
freq_max = 16000
freqs = np.array([(0, np.linspace(freq_min, freq_max, freq_num))], dtype=object)


filename = '../../data/chirp_kagome_centralSource_2-16kHz_0802/preprocessed/'


    
for setno, values in freqs:
    for j in tqdm(range(len(values))):
        with open(filename + '_' + str(values[j]) + '_' + str(setno) + '.pkl','rb') as f:
            real_data = pickle.load(f)

            for point in real_data:
                if point[1] > 110:
                    point[3] = -point[3]
                    point[2] = -point[2]
            
            real_data.dump(filename + '_' + str(values[j]) + '_' + str(setno) + '.pkl')
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 2527.51it/s]

# %%
## STEP 1.5: NORMALIZE SOUND INTENSITY BASED ON THE MIC'S FREQUENCY RESPONSE (OPTIONAL)
freqRespFile = "../../data/chirp_kagome_inCavity_2-16kHz_0806/freqResponse_2000_16000_500.pkl"
datafile = "../../data/chirp_kagome_inCavity_2-16kHz_0806/preprocessed/"
savefile = "../../data/chirp_kagome_inCavity_2-16kHz_0806/normalized/"
freqs = np.array([np.linspace(2000, 16000, 500)])

proc.normalize_intensity(freqRespFile = freqRespFile, datafile = datafile, savefile = savefile, freqs = freqs)
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 2590.68it/s]

# %%
## STEP 2: FOURIER TRANSFORM
freqs = np.array([np.linspace(2000, 20000, 500)])

L = 0.01

b_res = 300
b = np.linspace(0, 1.5+np.sqrt(3)/2, b_res) #GKMG sweep parameter


kxb = np.zeros(len(b))
kyb = np.zeros(len(b))
#kyb = np.linspace(0, 500, b_res)

for i in range(len(b)):
    if b[i] < 1:
        kxb[i] = b[i] * 4 * np.pi / (np.sqrt(3)*3 * L) 
        kyb[i] = 0
    elif b[i] < 1.5: 
        kxb[i] = 4 * np.pi / (np.sqrt(3)*3 * L) - 2 * np.pi / (3 * np.sqrt(3) * L) * (b[i]-1)
        kyb[i] = (b[i]-1) * 2 * np.pi / (3*L)
    else:
        kxb[i] = (1-(b[i]-1.5)*2/np.sqrt(3)) * np.pi/(np.sqrt(3) * L)
        kyb[i] = (1-(b[i]-1.5)*2/np.sqrt(3)) * np.pi/(3*L)



    
proc.fourier_chirps(size = (45, 50), 
                   freqs = freqs, 
                   kxs= kxb, 
                   kys = kyb, 
                   filename = '../../data/chirp_kagome_partialCover_0705/preprocessed/',
                   sfilename = '../../data/chirp_kagome_partialCover_0705/fourier/',
                   tag = '_scpfd')
# Out:
#   1%|          | 3/500 [00:00<00:20, 24.17it/s]
# Beginning chirp processing...
# 100%|██████████| 500/500 [00:16<00:00, 30.71it/s]

# %%
## 2D fourier transform

from tqdm import tqdm

folder = "../../data/kagome-01.21.2022-corner/"

with open(folder + "preprocessed/_9500.0_0.pkl",'rb') as f:
    real_data = pickle.load(f)

L = 0.01
kxmax = 4*np.pi/(3*np.sqrt(3) * L)
kymax = 2*np.pi/(3*L)
kxs = np.linspace(-3*kxmax, 3*kxmax, 200)
kys = np.linspace(-3*kymax, 3*kymax, 200)

reciprocal_data = np.zeros((len(kxs), len(kys)))
reciprocal_raw = np.zeros((len(kxs), len(kys)), dtype=complex)

    
'''
Elements of real_data are assumed to look like:
    0: X in mm
    1: Y in mm
    2: Amplitude
    3: Phase in degrees
'''

    
for yi in tqdm(range(len(kys))):
    for xi in range(len(kxs)):
        raw = np.array(
                [point[2] * np.exp(-1j * (kxs[xi] * (point[0]*10*np.sqrt(3)/4 / 1000) + kys[yi] * (point[1]*7.5 / 1000) + (point[3] / 57.2957795131))) 
                    for point in real_data]).sum()
        amplitude = np.abs(raw)
        reciprocal_data[yi][xi] = amplitude
        reciprocal_raw[yi][xi] = raw
# Out:
# 100%|██████████| 200/200 [00:02<00:00, 82.71it/s]

# %%
freq = 9.5
plt.figure(figsize=(12,12))
plt.imshow(reciprocal_data, cmap = 'binary', extent = [-3*kxmax, 3*kxmax, -3*kymax, 3*kymax], aspect = 'equal', origin = 'lower')

xBZ = np.zeros((7,7))
yBZ = np.zeros((7,7))

vec = np.array([[0,0], [np.sqrt(3), 1], [0, 2], [-np.sqrt(3),1], [-np.sqrt(3),-1], [0, -2], [np.sqrt(3),-1]])*kymax
xBZ[0] = [kxmax, 0.5*kxmax, -0.5*kxmax, -kxmax, -0.5*kxmax, 0.5*kxmax, kxmax]
yBZ[0] = [0, kymax, kymax, 0, -kymax, -kymax, 0]

for i in range(7):
    xBZ[i] = xBZ[0] + vec[i][0]
    yBZ[i] = yBZ[0] + vec[i][1]
    plt.plot(xBZ[i], yBZ[i], 'r-')


plt.xlabel("kx (1/m)")
plt.ylabel("ky (1/m)")
plt.title(str(freq)+" kHz")
plt.colorbar()

plt.savefig(folder + "fourier/figures/2D_DFT_{}kHz.png".format(freq))

# %%
# pseudo-"Density of states" plot
from tqdm import tqdm

folder = "../../data/chirp_kagome_inCavity_2-16kHz_0806/"


L = 0.01
kxmax = 4*np.pi/(3*np.sqrt(3) * L)
kymax = 2*np.pi/(3*L)
kxs = np.linspace(-3*kxmax, 3*kxmax, 50)
kys = np.linspace(-3*kymax, 3*kymax, 50)

    
'''
Elements of real_data are assumed to look like:
    0: X in mm
    1: Y in mm
    2: Amplitude
    3: Phase in degrees
'''

freq_num = 500
freq_min = 2000
freq_max = 16000
freqs = np.array([(0, np.linspace(freq_min, freq_max, freq_num))], dtype=object)
frequencies = np.linspace(freq_min, freq_max, freq_num)
dos = np.empty(freq_num)

for setno, values in freqs:
    for j in tqdm(range(len(values))):
        with open(folder + '_' + str(values[j]) + '_' + str(setno) + '.pkl','rb') as f:
            real_data = pickle.load(f)
            reciprocal_data = np.zeros((len(kxs), len(kys)))
            
            for yi in range(len(kys)):
                for xi in range(len(kxs)):
                    raw = np.array(
                            [point[2] * np.exp(-1j * (kxs[xi] * (point[0] / 1000) + kys[yi] * (point[1] / 1000) + (point[3] / 57.2957795131))) 
                                for point in real_data]).sum()
                    amplitude = np.abs(raw)
                    reciprocal_data[yi][xi] = amplitude
            
            dos[j] = np.sum(reciprocal_data)
# Out:
# 100%|██████████| 500/500 [24:46<00:00,  2.97s/it]

# %%
response = np.array(response)
dos = np.array(dos)
plt.figure(figsize=(10,8))
plt.plot(frequencies, dos, 'bo')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Response (V)")
plt.grid()
plt.savefig(folder + "response.png")

freqResp = [frequencies, dos]
np.array(freqResp).dump(folder + "freq-DOS.pkl")

with open(folder + "freq-DOS.pkl", 'rb') as f:
    data = pickle.load(f)

print(filename)
# Out:
# ../../data/chirp_kagome_inCavity_2-16kHz_0806/normalized/

# %%
import scipy
import cmath

'''
plt.plot(np.linspace(0,600,600), reciprocal_data[383])
peaks=scipy.signal.find_peaks(reciprocal_data[383])
print(peaks)
plt.figure()
plt.plot(np.linspace(0,600,600), reciprocal_data[:,261])
peaks=scipy.signal.find_peaks(reciprocal_data[261])
print(peaks)

print(reciprocal_data[385][261])
print(reciprocal_raw[385][261])

reciprocal_peak = reciprocal_raw[380:390, 256:266]
print(reciprocal_peak[0])
'''


reciprocal_phase = np.zeros(((len(reciprocal_raw)), len(reciprocal_raw[0])))

for i in range(len(reciprocal_raw)):
    for j in range(len(reciprocal_raw[0])):
        reciprocal_phase[i][j] = cmath.phase(reciprocal_raw[i][j])
        
plt.figure(figsize=(12,12))
plt.imshow(reciprocal_phase, cmap = 'twilight_shifted', extent = [-3*kxmax, 3*kxmax, -3*kxmax, 3*kxmax], aspect = 'equal', origin = 'lower')
plt.colorbar()
xBZ = [kxmax, 0.5*kxmax, -0.5*kxmax, -kxmax, -0.5*kxmax, 0.5*kxmax, kxmax]
yBZ = [0, kymax, kymax, 0, -kymax, -kymax, 0]
plt.plot(xBZ, yBZ, 'r-')
#plt.savefig(folder+"animations/phasePlot")

#print(reciprocal_phase[380:390, 256:266])

# %%
#GKMG sweeps

from tqdm import tqdm


freq_num = 500
freq_min = 2000
freq_max = 18000
freqs = np.array([(0, np.linspace(freq_min, freq_max, freq_num))], dtype=object)

L = 0.01
kxmax = 4*np.pi/(3*np.sqrt(3) * L)
kymax = 2*np.pi/(3*L)

b_res = 300
b = np.linspace(0, 1.5+np.sqrt(3)/2, b_res) #GKMG sweep parameter

kxb = np.zeros(len(b))
kyb = np.zeros(len(b))


for i in range(len(b)):
    if b[i] < 1:
        kxb[i] = b[i] * 4 * np.pi / (np.sqrt(3)*3 * L) 
        kyb[i] = 0
    elif b[i] < 1.5: 
        kxb[i] = 4 * np.pi / (np.sqrt(3)*3 * L) - 2 * np.pi / (3 * np.sqrt(3) * L) * (b[i]-1)
        kyb[i] = (b[i]-1) * 2 * np.pi / (3*L)
    else:
        kxb[i] = (1-(b[i]-1.5)*2/np.sqrt(3)) * np.pi/(np.sqrt(3) * L)
        kyb[i] = (1-(b[i]-1.5)*2/np.sqrt(3)) * np.pi/(3*L)
        



filename = '../../data/chirp_kagome_PLAcover_2-18kHz_0712_fewerSamples/preprocessed/'

reciprocal_data = np.zeros((freq_num, b_res))

    
for setno, values in freqs:
    for j in tqdm(range(len(values))):
        with open(filename + '_' + str(values[j]) + '_' + str(setno) + '.pkl','rb') as f:
            real_data = pickle.load(f)

            for i in range(b_res):
                amplitude = np.abs(np.array(
                        [point[2] * np.exp(1j * (kxb[i] * (point[0] / 1000) + kyb[i] * (point[1] / 1000) + (point[3] / 57.2957795131))) 
                            for point in real_data]).sum())

                reciprocal_data[j][i] = amplitude

folder = '../../data/chirp_kagome_PLAcover_2-18kHz_0712_fewerSamples/'



# GKMG sweep
plt.figure(figsize = (10, 10))
plt.imshow(reciprocal_data, cmap = 'binary', extent = [b[0], b[-1], freq_min, freq_max], aspect = 'auto', origin = 'lower')
plt.colorbar()
plt.xlabel("GKMG sweep parameter")
plt.ylabel("Frequency (Hz)")
plt.savefig(folder + "fourier/figures/GKMG_sweep")


plt.figure(figsize = (10, 10))
plt.imshow(np.log(reciprocal_data), cmap = 'binary', extent = [b[0], b[-1], freq_min, freq_max], aspect = 'auto', origin = 'lower')
plt.colorbar()
plt.xlabel("GKMG sweep parameter")
plt.ylabel("Frequency (Hz)")
plt.savefig(folder + "fourier/figures/GKMG_sweep_log")
# Out:
# 100%|██████████| 500/500 [00:52<00:00,  9.55it/s]

# %%
#GK'M'G sweeps

from tqdm import tqdm
import csv


freq_num = 951
freq_min = 1000
freq_max = 20000
freqs = np.array([(0, np.linspace(freq_min, freq_max, freq_num))], dtype=object)
freq_div1 = 8500
freq_div2 = 13000

L = 0.01
kxmax = 4*np.pi/(3*np.sqrt(3) * L)
kymax = 2*np.pi/(3*L)

b_res = 200
b = np.linspace(0, 1.5+np.sqrt(3)/2, b_res) #GKMG sweep parameter

kxb_low = np.zeros(len(b))
kyb_low = np.zeros(len(b))
kxb_high = np.zeros(len(b))
kyb_high = np.zeros(len(b))
kxb_flat = np.zeros(len(b))
kyb_flat = np.zeros(len(b))


for i in range(len(b)):
    if b[i] < 1:
        kxb_low[i] = b[i] * 2 * np.pi / (np.sqrt(3)*3 * L) 
        kyb_low[i] = b[i] * 2 * np.pi / (3 * L)
        
        #kxb_high[i] = b[i] * 2 * np.pi / (np.sqrt(3)*3 * L) 
        #kyb_high[i] = -(4 * np.pi / (3 * L) - b[i] * 2 * np.pi / (3 * L))
        kxb_flat[i] = 4 * np.pi / (3 * np.sqrt(3) * L) * b[i]
        kyb_flat[i] = 4 * np.pi / (3 * L)
    elif b[i] < 1.5: 
        kxb_low[i] = (2 * np.pi / (np.sqrt(3)*3 * L) - 2 * 2 * np.pi / (3 * np.sqrt(3) * L) * (b[i]-1))
        kyb_low[i] = 2 * np.pi / (3 * L) 
        
        
        #kxb_high[i] = 2 * np.pi / (np.sqrt(3)*3 * L) - 2 * 2 * np.pi / (3 * np.sqrt(3) * L) * (b[i]-1)
        #kyb_high[i] = -2 * np.pi / (3 * L) 
        kxb_flat[i] = 4 * np.pi / (3 * np.sqrt(3) * L) - 2 * np.pi / (3 * np.sqrt(3) * L) * (b[i]-1)
        kyb_flat[i] = 4 * np.pi / (3*L) + 2 * np.pi / (3 * L) * (b[i]-1)
    else:
        kxb_low[i] = 0
        kyb_low[i] = (2 * np.pi / (3 * L) - 2 * np.pi / (3 * L) *2 / np.sqrt(3) * (b[i]-1.5))
        #kxb_high[i] = 0
        #kyb_high[i] = -(2 * np.pi / (3 * L) + 2 * np.pi / (3 * L) *2 / np.sqrt(3) * (b[i]-1.5))
        kxb_flat[i] = (1- (b[i] - 1.5) * 2 / np.sqrt(3)) * np.pi / (np.sqrt(3) * L)
        kyb_flat[i] = 4 * np.pi / (3*L) + (1- 2 / (np.sqrt(3)) * (b[i]-1.5)) * np.pi / (3 * L)
        
    kxb_high[i] = -kxb_flat[i] + 6 * np.pi / (np.sqrt(3)*3 * L) 
    kyb_high[i] = kyb_flat[i]-2 * np.pi / (3 * L)



plt.figure()
plt.plot(kxb_flat, kyb_flat, 'b-')
plt.plot(kxb_high, kyb_high, 'g-')
plt.plot(kxb_low, kyb_low, 'b-')
plt.legend([''])

xBZ = np.zeros((7,7))
yBZ = np.zeros((7,7))

vec = np.array([[0,0], [np.sqrt(3), 1], [0, 2], [-np.sqrt(3),1], [-np.sqrt(3),-1], [0, -2], [np.sqrt(3),-1]])*kymax
xBZ[0] = [kxmax, 0.5*kxmax, -0.5*kxmax, -kxmax, -0.5*kxmax, 0.5*kxmax, kxmax]
yBZ[0] = [0, kymax, kymax, 0, -kymax, -kymax, 0]


for i in range(7):
    xBZ[i] = xBZ[0] + vec[i][0]
    yBZ[i] = yBZ[0] + vec[i][1]
    plt.plot(xBZ[i], yBZ[i], 'r-')

# %%
filename = '../../data/kagome-01.21.2022-corner/preprocessed/'

reciprocal_data = np.zeros((freq_num, b_res))
a = 10*np.sqrt(3)/2
    
for setno, values in freqs:
    for j in tqdm(range(len(values))):
        with open(filename + '_' + str(values[j]) + '_' + str(setno) + '.pkl','rb') as f:
            real_data = pickle.load(f)
            
            if values[j] <= freq_div1:
                
                for i in range(b_res):
                    amplitude = np.abs(np.array(
                            [point[2] * np.exp(1j * (kxb_low[i] * (point[0] *a/2 / 1000) + kyb_low[i] * (point[1]*7.5 / 1000) + (point[3] / 57.2957795131))) 
                                for point in real_data]).sum())
                    reciprocal_data[j][i] = amplitude
                   
            else:
                
                for i in range(b_res):
                    amplitude = np.abs(np.array(
                            [point[2] * np.exp(1j * (kxb_high[i] * (point[0] *a/2 / 1000) + kyb_high[i] * (point[1]*7.5 / 1000) + (point[3] / 57.2957795131))) 
                                for point in real_data]).sum())
                    reciprocal_data[j][i] = amplitude
'''           
            else:
                for i in range(b_res):
                    amplitude = np.abs(np.array(
                            [point[2] * np.exp(1j * (kxb_flat[i] * (point[0] *a/2 / 1000) + kyb_flat[i] * (point[1]*7.5 / 1000) + (point[3] / 57.2957795131))) 
                                for point in real_data]).sum())
                    reciprocal_data[j][i] = amplitude
   
'''
# Out:
# 100%|██████████| 951/951 [00:13<00:00, 69.46it/s]
# '           \n            else:\n                for i in range(b_res):\n                    amplitude = np.abs(np.array(\n                            [point[2] * np.exp(1j * (kxb_flat[i] * (point[0] *a/2 / 1000) + kyb_flat[i] * (point[1]*7.5 / 1000) + (point[3] / 57.2957795131))) \n                                for point in real_data]).sum())\n                    reciprocal_data[j][i] = amplitude\n   \n'

# %%
reciprocal_data_plot = np.zeros((freq_num, b_res))


for i in range(len(reciprocal_data)):
    reciprocal_data_plot[i] = reciprocal_data[i]#/np.average(reciprocal_data[i])
    #reciprocal_data_plot[i] = reciprocal_data[i]/reciprocal_data[i][0]
    #reciprocal_data_plot[i] = reciprocal_data[i]/reciprocal_data[i].max()



folder = '../../data/kagome-01.21.2022-corner/'

b_sim = []
band1 = []
band2 = []
band3 = []

with open('../../data/simulation/kagome_PLAcover_clean-allBands.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    
    for row in reader:
        b_sim.append(float(row[0]))
        band1.append(float(row[1])/1000)
        band2.append(float(row[2])/1000)
        band3.append(float(row[3])/1000)


    
# GKMG sweep
plt.figure(figsize = (10, 10))
color_map = plt.cm.get_cmap('inferno')
reversed_magma = color_map.reversed()
plt.imshow(reciprocal_data_plot, cmap = reversed_magma, extent = [b[0], b[-1], freq_min/1000, freq_max/1000], aspect = 'auto', origin = 'lower', interpolation='none')
plt.plot(b_sim, band1, 'b-',linewidth = 0.3)
plt.plot(b_sim, band2, 'b-',linewidth = 0.3)
plt.plot(b_sim, band3, 'b-',linewidth = 0.3)
plt.colorbar(label = 'Amplitude (V)')
plt.ylabel("Frequency (kHz)", fontsize = 20)
plt.axis([b[0], b[-1], freq_min/1000, freq_max/1000])
plt.yticks(np.linspace(2, 16, 8), fontsize = 20)
plt.xticks([0, 1, 1.5, b[-1]], ['\u0393', 'K', 'M', '\u0393'], fontsize=25)
plt.savefig(folder + "fourier/figures/GK'M'G_sweep2", interpolation='none')


plt.figure(figsize = (10, 10))
plt.imshow(np.log(reciprocal_data_plot), cmap = 'binary', extent = [b[0], b[-1], freq_min/1000, freq_max/1000], aspect = 'auto', origin = 'lower')
plt.colorbar(label = 'Amplitude (V)')
plt.plot(b_sim, band1, 'y-')
plt.plot(b_sim, band2, 'y-')
plt.plot(b_sim, band3, 'y-')
plt.ylabel("Frequency (kHz)")
plt.axis([b[0], b[-1], freq_min/1000, freq_max/1000])
plt.savefig(folder + "fourier/figures/GK'M'G_sweep2_binary")
# Out:
# <ipython-input-70-1c52b0584e75>:43: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "interpolation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(folder + "fourier/figures/GK'M'G_sweep2", interpolation='none')

# %%
# Amplitude plot


from matplotlib import patches as ptc
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.colors as colors

folder = "../../data/chirp_kagome_PVCcover_2-16kHz_0719/"
with open(folder + "preprocessed/_10024.048096192386_0.pkl",'rb') as f:
    real_data = pickle.load(f)  

amp = real_data[:, 2]
amp = amp.tolist()
max_amp = max(amp)

fig = plt.figure(figsize=(8,8))
ax = fig.gca()
ax.set_aspect("equal")
ax.set_xlim(-5, 180)
ax.set_ylim(-5, 165)
ax.set_xlabel("x distance (mm)")
ax.set_ylabel("y distance (mm)")
cbar = fig.colorbar(cm.ScalarMappable(norm=colors.Normalize(vmin=0, vmax=max_amp), cmap = "viridis"), ax=ax, label="Lock-in signal (V)")

    
for point in real_data:
    x_center = point[0]
    y_center = point[1]
    
    ampdata.append(point[2])
    phasedata.append(point[3])
    
    
    circle = ptc.Ellipse((x_center, y_center), 
                     width = radius*2, 
                     height = radius*2, 
                     edgecolor='black', facecolor = plt.cm.viridis(ampdata[-1]/max_amp),
                     fill = True, alpha = 1)
    cavities.append(circle)
    ax.add_patch(cavities[-1])

# %%
plt.figure(figsize = (10, 10))
plt.imshow(np.log(reciprocal_data), cmap = 'binary', extent = [b[0], b[-1], freq_min, freq_max], aspect = 'auto', origin = 'lower')

# %%
# y axis sweeps

from tqdm import tqdm


freq_num = 500
freq_min = 2000
freq_max = 18000
freqs = np.array([(0, np.linspace(freq_min, freq_max, freq_num))], dtype=object)

L = 0.01
kxmax = 4*np.pi/(3*np.sqrt(3) * L)
kymax = 2*np.pi/(3*L)

b_res = 300
b = np.linspace(0, 1.5+np.sqrt(3)/2, b_res) #GKMG sweep parameter

kxb = np.zeros(len(b))
kyb = np.zeros(len(b))
kyb = np.linspace(0, 1000, b_res)



filename = '../../data/chirp_kagome_PLAcover_2-18kHz_0712/preprocessed/'

reciprocal_data = np.zeros((freq_num, b_res))

    
for setno, values in freqs:
    for j in tqdm(range(len(values))):
        with open(filename + '_' + str(values[j]) + '_' + str(setno) + '.pkl','rb') as f:
            real_data = pickle.load(f)

            for i in range(b_res):
                amplitude = np.abs(np.array(
                        [point[2] * np.exp(-1j * (kxb[i] * (point[0] / 1000) + kyb[i] * (point[1] / 1000) + (point[3] / 57.2957795131))) 
                            for point in real_data]).sum())

                reciprocal_data[j][i] = amplitude

folder = '../../data/chirp_kagome_PLAcover_2-18kHz_0712/'


# y-axis sweep
plt.figure(figsize = (10, 10))
plt.imshow(reciprocal_data, cmap = 'binary', extent = [kyb[0], kyb[-1], freq_min, freq_max], aspect = 'auto', origin = 'lower')
plt.colorbar()
plt.xlabel("ky (1/m)")
plt.ylabel("Frequency (Hz)")
plt.savefig(folder + "fourier/figures/yaxis_sweep")
xBZ = [kxmax, 0.5*kxmax, -0.5*kxmax, -kxmax, -0.5*kxmax, 0.5*kxmax, kxmax]
yBZ = [0, kymax, kymax, 0, -kymax, -kymax, 0]
#plt.figure()
#plt.plot(xBZ, yBZ, 'r-')

plt.figure(figsize = (10, 10))
plt.imshow(np.log(reciprocal_data), cmap = 'binary', extent = [kyb[0], kyb[-1], freq_min, freq_max], aspect = 'auto', origin = 'lower')
plt.colorbar()
plt.xlabel("ky (1/m)")
plt.ylabel("Frequency (Hz)")
plt.savefig(folder + "fourier/figures/yaxis_sweep_log")
# Out:
# 100%|██████████| 500/500 [02:31<00:00,  3.29it/s]

# %%
# Find peaks in the band structure and scatter them

from scipy.signal import find_peaks

peaks = []
peak_count = 2

freqs = np.linspace(freq_min, freq_max, freq_num)

scatterX = []
scatterY = []

folder = '../../data/kagome-01.21.2022-corner/'

for i in range(680): #214-428: 12-18 kHZ
    
    def peakValue(index):
        return reciprocal_data[i][index]

    peak_indices, _ = find_peaks(reciprocal_data[i])
    peak_indices = list(peak_indices)
    peak_indices.sort(key = peakValue, reverse = True)
    
    for j in range(peak_count):
        scatterX.append(b[peak_indices[j]])
        scatterY.append(freqs[i])

plt.figure(figsize=(8,10))
plt.plot(b_sim, np.array(band1), 'r-')
plt.plot(b_sim, np.array(band2), 'r-')
plt.plot(b_sim, np.array(band3), 'r-')
plt.scatter(scatterX, np.array(scatterY)/1000, 10)
plt.ylabel("Frequency (kHz)", fontsize = 20)
plt.axis([b[0], b[-1], freq_min/1000, freq_max/1000])
plt.yticks(np.linspace(2, 16, 8), fontsize = 20)
plt.yticks(np.linspace(2, 16, 8), fontsize = 20)
plt.xticks([0, 1, 1.5, b[-1]], ['\u0393', 'K', 'M', '\u0393'], fontsize=25)
plt.grid()
plt.savefig(folder + "fourier/figures/GKMG_sweep2_peaks_" + str(peak_count))

# GKMG sweep




        
print(folder)
# Out:
# ../../data/kagome-01.21.2022-corner/

# %%
# Amplitude plot


from matplotlib import patches as ptc
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.colors as colors

folder = "../../data/chirp_kagome_6transducer_2-16kHz_0812/"
with open(folder + "preprocessed/_14176.352705410822_0.pkl",'rb') as f:
    real_data = pickle.load(f)  

amp = real_data[:, 2]
amp = amp.tolist()
max_amp = max(amp)

fig = plt.figure(figsize=(8,8))
ax = fig.gca()
ax.set_aspect("equal")
ax.set_xlim(-5, 180)
ax.set_ylim(-5, 190)
ax.set_xlabel("x distance (mm)")
ax.set_ylabel("y distance (mm)")
cbar = fig.colorbar(cm.ScalarMappable(norm=colors.Normalize(vmin=0, vmax=max_amp), cmap = "pink"), ax=ax, label="Lock-in signal (V)")

    
for point in real_data:
    x_center = point[0]
    y_center = point[1]
    
    ampdata.append(point[2])
    phasedata.append(point[3])
    
    
    circle = ptc.Ellipse((x_center, y_center), 
                     width = radius*2, 
                     height = radius*2, 
                     edgecolor='black', facecolor = plt.cm.pink(ampdata[-1]/max_amp),
                     fill = True, alpha = 1)
    cavities.append(circle)
    ax.add_patch(cavities[-1])

plt.savefig(folder + "animations/amplitude_plot.png")

# %%
# Phase plot


from matplotlib import patches as ptc
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.colors as colors

folder = "../../data/chirp_kagome_6transducer_2-16kHz_0812/"
with open(folder + "preprocessed/_14176.352705410822_0.pkl",'rb') as f:
    real_data = pickle.load(f)  

amp = real_data[:, 2]
amp = amp.tolist()
max_amp = max(amp)

fig = plt.figure(figsize=(8,8))
ax = fig.gca()
ax.set_aspect("equal")
ax.set_xlim(-5, 180)
ax.set_ylim(-5, 185)
ax.set_xlabel("x distance (mm)")
ax.set_ylabel("y distance (mm)")
cbar = fig.colorbar(cm.ScalarMappable(norm=colors.Normalize(vmin=-1.0, vmax=1.0), cmap = "seismic"), ax=ax, label="phase (deg)")
ampdata = []
phasedata = []
phase_real = []
    
for point in real_data:
    x_center = point[0]
    y_center = point[1]
    
    ampdata.append(point[2])
    phasedata.append(point[3])
    
    phase_real.append(np.sin(np.deg2rad(phasedata[-1]*1.0+16))) 
    
    circle = ptc.Ellipse((x_center, y_center), 
                     width = radius*2, 
                     height = radius*2, 
                     edgecolor='black', facecolor = plt.cm.seismic((phase_real[-1]+1.0)/2.0),
                     fill = True, alpha = 1)
    cavities.append(circle)
    ax.add_patch(cavities[-1])
    
plt.savefig(folder + "animations/phase_plot.png")

# %%
from matplotlib import patches as ptc
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.cm as cm
import matplotlib.colors as colors


kagome_lattice = [((-0.8660,  0.0000), 0.35),
                ((-0.4330,  0.750), 0.35),
                (( 0.4330,  0.750), 0.35),
                (( 0.8660,  0.0000), 0.35),
                (( 0.4330, -0.750), 0.35),
                ((-0.4330, -0.750), 0.35)]


folder = "../../data/chirp_kagome_2transducer_2-16kHz_0816/"

with open(folder + "preprocessed/_7218.436873747495_0.pkl",'rb') as f:
    real_data = pickle.load(f)    
    

lattice_offset = kagome_lattice[4][0]
unit_cell = 10.0
radius = kagome_lattice[0][1]*unit_cell

amp = real_data[:, 2]
amp = amp.tolist()
max_amp = max(amp)
#max_amp = 1.0

freq = 14.4


cavities = []
ampdata = []
phasedata = []
t = 0
dt = 0.1

freq_min = 2000
freq_max = 16000
freq_num = 500

phase1 = 0
phase2 = 0

freqs = np.array([(0, np.linspace(freq_min, freq_max, freq_num))], dtype=object)
phaseDiff = np.zeros(freq_num)
filename = "../../data/chirp_kagome_2transducer_2-16kHz_0818/preprocessed/"

for setno, values in freqs:
    for j in tqdm(range(len(values))):
        with open(filename + '_' + str(values[j]) + '_' + str(setno) + '.pkl','rb') as f:
            real_data = pickle.load(f)
            
            
            for point in real_data:
                x_center = point[0]
                y_center = point[1]
                
                


                if (y_center == 12 * 7.5) and (x_center > 75) and (x_center < 90):
                    phase1 = point[3]

                if (y_center == 12 * 7.5) and (x_center > 90) and (x_center < 105):
                    phase2 = point[3]
                
                phaseDiff[j] = phase1 - phase2
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 3642.16it/s]

# %%
frequencies = np.linspace(freq_min, freq_max, freq_num)
error = np.zeros(freq_num)

for i in range(freq_num):
    if phaseDiff[i] < 0:
        error[i] = np.abs(phaseDiff[i] + 180)
    else:
        error[i] = np.abs(180 - phaseDiff[i])
        

plt.figure(figsize=(10,6))
plt.plot(frequencies, phaseDiff, 'b.')
plt.yticks(np.linspace(-210, 210, 11))
plt.xlabel("freuqency (Hz)", )
plt.ylabel("phase difference (deg)")
plt.grid()
plt.savefig("../../data/chirp_kagome_2transducer_2-16kHz_0818/phaseDifference.png")


plt.figure(figsize=(10,6))
plt.plot(frequencies, error, 'b.')
plt.yticks(np.linspace(-10, 160, 18))
plt.xlabel("freuqency (Hz)", )
plt.ylabel("error (deg)")
plt.grid()
plt.savefig("../../data/chirp_kagome_2transducer_2-16kHz_0818/phaseError.png")

# %%
# Animating chirp scans

from matplotlib import patches as ptc
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.cm as cm
import matplotlib.colors as colors


kagome_lattice = [((-0.8660,  0.0000), 0.35),
                ((-0.4330,  0.750), 0.35),
                (( 0.4330,  0.750), 0.35),
                (( 0.8660,  0.0000), 0.35),
                (( 0.4330, -0.750), 0.35),
                ((-0.4330, -0.750), 0.35)]


folder = "../../data/kagome-01.12.2022/"

with open(folder + "preprocessed/_14575.757575757576_0.pkl",'rb') as f:
    real_data = pickle.load(f)    
    

lattice_offset = kagome_lattice[4][0]
unit_cell = 10.0
radius = kagome_lattice[0][1]*unit_cell

amp = real_data[:, 2]
amp = amp.tolist()
max_amp = max(amp)
#max_amp = 1.0

freq = 14.58
fig = plt.figure(figsize=(8,8))
ax = fig.gca()
ax.set_aspect("equal")
ax.set_xlim(-50, 50)
ax.set_ylim(-50, 50)
ax.set_xlabel("x distance (mm)", fontsize=20)
ax.set_ylabel("y distance (mm)", fontsize=20)
ax.set_title(str(freq) + " kHz, real space", fontsize=20)
cbar = fig.colorbar(cm.ScalarMappable(norm=colors.Normalize(vmin=-max_amp, vmax=max_amp), cmap = "seismic"), ax=ax, label="Lock-in signal (V)")

cavities = []
ampdata = []
phasedata = []
t = 0
dt = 0.1

for point in real_data:
    x_center = point[0]
    y_center = point[1]
    
    if (y_center == 12 * 7.5) and (x_center > 75) and (x_center < 90):
        print("transducer 1 phase: " + str(point[3]))
    
    if (y_center == 12 * 7.5) and (x_center > 90) and (x_center < 105):
        print("transducer 2 phase: " + str(point[3]))
    
    #ampdata.append(np.sqrt(point[2])*np.sqrt(max_amp))
    ampdata.append(point[2])
    phasedata.append(point[3])
    

    
    pressure = ampdata[-1]*np.sin(np.deg2rad(phasedata[-1]))
    #pressure = np.sin(np.deg2rad(phasedata[-1]))

    circle = ptc.Ellipse((x_center, y_center), 
                     width = radius*2, 
                     height = radius*2, 
                     edgecolor='black', facecolor = plt.cm.seismic((pressure+max_amp)/(2.0*max_amp)),
                     fill = True, alpha = 1)
    cavities.append(circle)
    ax.add_patch(cavities[-1])
    
def init():
    """initialize animation"""
    global cavities, t
    
    t = 0
    
    for i in range(len(cavities)):
        pressure = ampdata[i]*np.sin(np.deg2rad(phasedata[i])+t)
        #pressure = np.sin(np.deg2rad(phasedata[i]) + t)
        
        cavities[i].set_facecolor(plt.cm.seismic((pressure+max_amp)/(2.0*max_amp)))
                             
    return cavities
    
def animate(j):
    global t, dt, cavities, ampdata, phasedata
    t += dt
                            
    for i in range(len(cavities)):
        pressure = ampdata[i]*np.sin(np.deg2rad(phasedata[i]+j))
        #pressure = np.sin(np.deg2rad(phasedata[i]) + j)
        cavities[i].set_facecolor(plt.cm.seismic((pressure+max_amp)/(2.0*max_amp)))
                             
    return cavities

ani = animation.FuncAnimation(fig, animate, frames = 360, interval = 20, blit = True, init_func = init)
print(max_amp)
# Out:
# 0.267824

# %%
ani.save(folder + 'animations/' + str(freq) + 'kHz.gif', writer = 'imagemagick', fps = 60)

# %%
from IPython.display import HTML, Image

Image(url = folder + 'animations/' + str(freq) + 'kHz_sqrt.gif')
# Out:
# <img src="../../data/kagome-01.12.2022/animations/14.58kHz_sqrt.gif"/>

# %%
## STEP 3: COMBINE DATA

freqs = np.array([(0, np.linspace(6000, 20000, 300))], dtype=object)
    
proc.combine_data(size = (200, 200), 
                 freqs = freqs, 
                 kmin = 0, 
                 kmax = 1000, 
                 kmindisp = 0, 
                 kmaxdisp = 500,
                 ksamples = 701, 
                 filename = '../../data/chirp_extkag_6000-20000Hz_0624/fourier/',    ##CHANGE THIS
                 #datapath = '../../data/chirp_0621_final',       ##CHANGE THIS
                 figsize = (10, 10), 
                 tag = '_scpfdcal', 
                 dpi = 200,
                 cutoff = 1000.0,
                 rec_cutoff = -1000+81.0,
                 abs_cutoff = 1.5, 
                 meanp_cutoff = 1.5,
                 allplots = False, 
                 alplc = 0, 
                 alphc = 24072,
                 nimg = True, 
                 limg = True, 
                 scatter = True,
                 flatness_plot = True, 
                 normalize = False,
                 reconstruct = True,
                 flatness_peak_fit = True,
                 flatpeak_p0 = [25, 12200, 50],
                 flat_peak_start = 0, 
                 flat_peak_end = 15000)
# Out:
# Beginning chirp processing...
# 0
# 46
# 93
# 140
# 187
# 234
# 280
# 327
# 374
# 421
# 468
# 515
# 561
# 608
# 655
# 702
# 749
# 795
# 842
# 889
# 936
# 983
# 1030
# 1076
# 1123
# 1170
# 1217
# 1264
# 1311
# 1357
# 1404
# 1451
# 1498
# 1545
# 1591
# 1638
# 1685
# 1732
# 1779
# 1826
# 1872
# 1919
# 1966
# 2013
# 2060
# 2107
# 2153
# 2200
# 2247
# 2294
# 2341
# 2387
# 2434
# 2481
# 2528
# 2575
# 2622
# 2668
# 2715
# 2762
# 2809
# 2856
# 2903
# 2949
# 2996
# 3043
# 3090
# 3137
# 3183
# 3230
# 3277
# 3324
# 3371
# 3418
# 3464
# 3511
# 3558
# 3605
# 3652
# 3698
# 3745
# 3792
# 3839
# 3886
# 3933
# 3979
# 4026
# 4073
# 4120
# 4167
# 4214
# 4260
# 4307
# 4354
# 4401
# 4448
# 4494
# 4541
# 4588
# 4635
# 4682
# 4729
# 4775
# 4822
# 4869
# 4916
# 4963
# 5010
# 5056
# 5103
# 5150
# 5197
# 5244
# 5290
# 5337
# 5384
# 5431
# 5478
# 5525
# 5571
# 5618
# 5665
# 5712
# 5759
# 5806
# 5852
# 5899
# 5946
# 5993
# 6040
# 6086
# 6133
# 6180
# 6227
# 6274
# 6321
# 6367
# 6414
# 6461
# 6508
# 6555
# 6602
# 6648
# 6695
# 6742
# 6789
# 6836
# 6882
# 6929
# 6976
# 7023
# 7070
# 7117
# 7163
# 7210
# 7257
# 7304
# 7351
# 7397
# 7444
# 7491
# 7538
# 7585
# 7632
# 7678
# 7725
# 7772
# 7819
# 7866
# 7913
# 7959
# 8006
# 8053
# 8100
# 8147
# 8193
# 8240
# 8287
# 8334
# 8381
# 8428
# 8474
# 8521
# 8568
# 8615
# 8662
# 8709
# 8755
# 8802
# 8849
# 8896
# 8943
# 8989
# 9036
# 9083
# 9130
# 9177
# 9224
# 9270
# 9317
# 9364
# 9411
# 9458
# 9505
# 9551
# 9598
# 9645
# 9692
# 9739
# 9785
# 9832
# 9879
# 9926
# 9973
# 10020
# 10066
# 10113
# 10160
# 10207
# 10254
# 10301
# 10347
# 10394
# 10441
# 10488
# 10535
# 10581
# 10628
# 10675
# 10722
# 10769
# 10816
# 10862
# 10909
# 10956
# 11003
# 11050
# 11096
# 11143
# 11190
# 11237
# 11284
# 11331
# 11377
# 11424
# 11471
# 11518
# 11565
# 11612
# 11658
# 11705
# 11752
# 11799
# 11846
# 11892
# 11939
# 11986
# 12033
# 12080
# 12127
# 12173
# 12220
# 12267
# 12314
# 12361
# 12408
# 12454
# 12501
# 12548
# 12595
# 12642
# 12688
# 12735
# 12782
# 12829
# 12876
# 12923
# 12969
# 13016
# 13063
# 13110
# 13157
# 13204
# 13250
# 13297
# 13344
# 13391
# 13438
# 13484
# 13531
# 13578
# 13625
# 13672
# 13719
# 13765
# 13812
# 13859
# 13906
# 13953
# 14000
# [7.93599242e+00 1.22028693e+04 3.13095092e+03]

# %%
with open('../../data/chirp_kagome_inCavity_2-16kHz_0806/freqResponse_2000_16000_500.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
with open('../../data/chirp_kagome_inCavity_2-16kHz_0806/freqResponse_2000_16000_500.pkl', 'rb') as f:
    data = pickle.load(f)
print(data)
freq, response = data

resp_plot = np.zeros((len(response),3))

for i in range(len(response)):
    for j in range(3):
        resp_plot[i][j] = response[i]
        
plt.figure(figsize = (10, 10))
plt.imshow(np.log(resp_plot), cmap = 'binary', extent = [0, 1, 2000, 16000], aspect = 'auto', origin = 'lower')
plt.colorbar()
plt.ylabel('frequency (Hz)')
plt.savefig("../../data/chirp_kagome_inCavity_2-16kHz_0806/frequencyResponse/colorPlot.png")

plt.figure()
plt.plot(freq, response, 'b-')
plt.axis([0, 16500, 0, 1.2])
plt.xlabel("frequency (Hz)")
plt.ylabel("response amplitude (V)")
plt.savefig("../../data/chirp_kagome_inCavity_2-16kHz_0806/frequencyResponse/linePlot.png")
# Out:
# [array([ 2000.        ,  2028.05611222,  2056.11222445,  2084.16833667,
#         2112.2244489 ,  2140.28056112,  2168.33667335,  2196.39278557,
#         2224.4488978 ,  2252.50501002,  2280.56112224,  2308.61723447,
#         2336.67334669,  2364.72945892,  2392.78557114,  2420.84168337,
#         2448.89779559,  2476.95390782,  2505.01002004,  2533.06613226,
#         2561.12224449,  2589.17835671,  2617.23446894,  2645.29058116,
#         2673.34669339,  2701.40280561,  2729.45891784,  2757.51503006,
#         2785.57114228,  2813.62725451,  2841.68336673,  2869.73947896,
#         2897.79559118,  2925.85170341,  2953.90781563,  2981.96392786,
#         3010.02004008,  3038.0761523 ,  3066.13226453,  3094.18837675,
#         3122.24448898,  3150.3006012 ,  3178.35671343,  3206.41282565,
#         3234.46893788,  3262.5250501 ,  3290.58116232,  3318.63727455,
#         3346.69338677,  3374.749499  ,  3402.80561122,  3430.86172345,
#         3458.91783567,  3486.9739479 ,  3515.03006012,  3543.08617234,
#         3571.14228457,  3599.19839679,  3627.25450902,  3655.31062124,
#         3683.36673347,  3711.42284569,  3739.47895792,  3767.53507014,
#         3795.59118236,  3823.64729459,  3851.70340681,  3879.75951904,
#         3907.81563126,  3935.87174349,  3963.92785571,  3991.98396794,
#         4020.04008016,  4048.09619238,  4076.15230461,  4104.20841683,
#         4132.26452906,  4160.32064128,  4188.37675351,  4216.43286573,
#         4244.48897796,  4272.54509018,  4300.6012024 ,  4328.65731463,
#         4356.71342685,  4384.76953908,  4412.8256513 ,  4440.88176353,
#         4468.93787575,  4496.99398798,  4525.0501002 ,  4553.10621242,
#         4581.16232465,  4609.21843687,  4637.2745491 ,  4665.33066132,
#         4693.38677355,  4721.44288577,  4749.498998  ,  4777.55511022,
#         4805.61122244,  4833.66733467,  4861.72344689,  4889.77955912,
#         4917.83567134,  4945.89178357,  4973.94789579,  5002.00400802,
#         5030.06012024,  5058.11623246,  5086.17234469,  5114.22845691,
#         5142.28456914,  5170.34068136,  5198.39679359,  5226.45290581,
#         5254.50901804,  5282.56513026,  5310.62124248,  5338.67735471,
#         5366.73346693,  5394.78957916,  5422.84569138,  5450.90180361,
#         5478.95791583,  5507.01402806,  5535.07014028,  5563.12625251,
#         5591.18236473,  5619.23847695,  5647.29458918,  5675.3507014 ,
#         5703.40681363,  5731.46292585,  5759.51903808,  5787.5751503 ,
#         5815.63126253,  5843.68737475,  5871.74348697,  5899.7995992 ,
#         5927.85571142,  5955.91182365,  5983.96793587,  6012.0240481 ,
#         6040.08016032,  6068.13627255,  6096.19238477,  6124.24849699,
#         6152.30460922,  6180.36072144,  6208.41683367,  6236.47294589,
#         6264.52905812,  6292.58517034,  6320.64128257,  6348.69739479,
#         6376.75350701,  6404.80961924,  6432.86573146,  6460.92184369,
#         6488.97795591,  6517.03406814,  6545.09018036,  6573.14629259,
#         6601.20240481,  6629.25851703,  6657.31462926,  6685.37074148,
#         6713.42685371,  6741.48296593,  6769.53907816,  6797.59519038,
#         6825.65130261,  6853.70741483,  6881.76352705,  6909.81963928,
#         6937.8757515 ,  6965.93186373,  6993.98797595,  7022.04408818,
#         7050.1002004 ,  7078.15631263,  7106.21242485,  7134.26853707,
#         7162.3246493 ,  7190.38076152,  7218.43687375,  7246.49298597,
#         7274.5490982 ,  7302.60521042,  7330.66132265,  7358.71743487,
#         7386.77354709,  7414.82965932,  7442.88577154,  7470.94188377,
#         7498.99799599,  7527.05410822,  7555.11022044,  7583.16633267,
#         7611.22244489,  7639.27855711,  7667.33466934,  7695.39078156,
#         7723.44689379,  7751.50300601,  7779.55911824,  7807.61523046,
#         7835.67134269,  7863.72745491,  7891.78356713,  7919.83967936,
#         7947.89579158,  7975.95190381,  8004.00801603,  8032.06412826,
#         8060.12024048,  8088.17635271,  8116.23246493,  8144.28857715,
#         8172.34468938,  8200.4008016 ,  8228.45691383,  8256.51302605,
#         8284.56913828,  8312.6252505 ,  8340.68136273,  8368.73747495,
#         8396.79358717,  8424.8496994 ,  8452.90581162,  8480.96192385,
#         8509.01803607,  8537.0741483 ,  8565.13026052,  8593.18637275,
#         8621.24248497,  8649.29859719,  8677.35470942,  8705.41082164,
#         8733.46693387,  8761.52304609,  8789.57915832,  8817.63527054,
#         8845.69138277,  8873.74749499,  8901.80360721,  8929.85971944,
#         8957.91583166,  8985.97194389,  9014.02805611,  9042.08416834,
#         9070.14028056,  9098.19639279,  9126.25250501,  9154.30861723,
#         9182.36472946,  9210.42084168,  9238.47695391,  9266.53306613,
#         9294.58917836,  9322.64529058,  9350.70140281,  9378.75751503,
#         9406.81362725,  9434.86973948,  9462.9258517 ,  9490.98196393,
#         9519.03807615,  9547.09418838,  9575.1503006 ,  9603.20641283,
#         9631.26252505,  9659.31863727,  9687.3747495 ,  9715.43086172,
#         9743.48697395,  9771.54308617,  9799.5991984 ,  9827.65531062,
#         9855.71142285,  9883.76753507,  9911.82364729,  9939.87975952,
#         9967.93587174,  9995.99198397, 10024.04809619, 10052.10420842,
#        10080.16032064, 10108.21643287, 10136.27254509, 10164.32865731,
#        10192.38476954, 10220.44088176, 10248.49699399, 10276.55310621,
#        10304.60921844, 10332.66533066, 10360.72144289, 10388.77755511,
#        10416.83366733, 10444.88977956, 10472.94589178, 10501.00200401,
#        10529.05811623, 10557.11422846, 10585.17034068, 10613.22645291,
#        10641.28256513, 10669.33867735, 10697.39478958, 10725.4509018 ,
#        10753.50701403, 10781.56312625, 10809.61923848, 10837.6753507 ,
#        10865.73146293, 10893.78757515, 10921.84368737, 10949.8997996 ,
#        10977.95591182, 11006.01202405, 11034.06813627, 11062.1242485 ,
#        11090.18036072, 11118.23647295, 11146.29258517, 11174.34869739,
#        11202.40480962, 11230.46092184, 11258.51703407, 11286.57314629,
#        11314.62925852, 11342.68537074, 11370.74148297, 11398.79759519,
#        11426.85370741, 11454.90981964, 11482.96593186, 11511.02204409,
#        11539.07815631, 11567.13426854, 11595.19038076, 11623.24649299,
#        11651.30260521, 11679.35871743, 11707.41482966, 11735.47094188,
#        11763.52705411, 11791.58316633, 11819.63927856, 11847.69539078,
#        11875.75150301, 11903.80761523, 11931.86372745, 11959.91983968,
#        11987.9759519 , 12016.03206413, 12044.08817635, 12072.14428858,
#        12100.2004008 , 12128.25651303, 12156.31262525, 12184.36873747,
#        12212.4248497 , 12240.48096192, 12268.53707415, 12296.59318637,
#        12324.6492986 , 12352.70541082, 12380.76152305, 12408.81763527,
#        12436.87374749, 12464.92985972, 12492.98597194, 12521.04208417,
#        12549.09819639, 12577.15430862, 12605.21042084, 12633.26653307,
#        12661.32264529, 12689.37875752, 12717.43486974, 12745.49098196,
#        12773.54709419, 12801.60320641, 12829.65931864, 12857.71543086,
#        12885.77154309, 12913.82765531, 12941.88376754, 12969.93987976,
#        12997.99599198, 13026.05210421, 13054.10821643, 13082.16432866,
#        13110.22044088, 13138.27655311, 13166.33266533, 13194.38877756,
#        13222.44488978, 13250.501002  , 13278.55711423, 13306.61322645,
#        13334.66933868, 13362.7254509 , 13390.78156313, 13418.83767535,
#        13446.89378758, 13474.9498998 , 13503.00601202, 13531.06212425,
#        13559.11823647, 13587.1743487 , 13615.23046092, 13643.28657315,
#        13671.34268537, 13699.3987976 , 13727.45490982, 13755.51102204,
#        13783.56713427, 13811.62324649, 13839.67935872, 13867.73547094,
#        13895.79158317, 13923.84769539, 13951.90380762, 13979.95991984,
#        14008.01603206, 14036.07214429, 14064.12825651, 14092.18436874,
#        14120.24048096, 14148.29659319, 14176.35270541, 14204.40881764,
#        14232.46492986, 14260.52104208, 14288.57715431, 14316.63326653,
#        14344.68937876, 14372.74549098, 14400.80160321, 14428.85771543,
#        14456.91382766, 14484.96993988, 14513.0260521 , 14541.08216433,
#        14569.13827655, 14597.19438878, 14625.250501  , 14653.30661323,
#        14681.36272545, 14709.41883768, 14737.4749499 , 14765.53106212,
#        14793.58717435, 14821.64328657, 14849.6993988 , 14877.75551102,
#        14905.81162325, 14933.86773547, 14961.9238477 , 14989.97995992,
#        15018.03607214, 15046.09218437, 15074.14829659, 15102.20440882,
#        15130.26052104, 15158.31663327, 15186.37274549, 15214.42885772,
#        15242.48496994, 15270.54108216, 15298.59719439, 15326.65330661,
#        15354.70941884, 15382.76553106, 15410.82164329, 15438.87775551,
#        15466.93386774, 15494.98997996, 15523.04609218, 15551.10220441,
#        15579.15831663, 15607.21442886, 15635.27054108, 15663.32665331,
#        15691.38276553, 15719.43887776, 15747.49498998, 15775.5511022 ,
#        15803.60721443, 15831.66332665, 15859.71943888, 15887.7755511 ,
#        15915.83166333, 15943.88777555, 15971.94388778, 16000.        ]), [0.014187, 0.01444337525773196, 0.014886961855670107, 0.015379662886597938, 0.01598369375, 0.016666494845360823, 0.017317742268041236, 0.018079891666666667, 0.018842991752577316, 0.019652147916666668, 0.020456428125, 0.02132364583333333, 0.022133625, 0.0229734875, 0.024021817346938777, 0.025054434693877553, 0.026110094897959183, 0.027095999999999995, 0.028151664285714285, 0.029236586734693877, 0.030266102040816333, 0.0314277306122449, 0.03252824387755101, 0.03344127040816326, 0.03444649285714286, 0.03549281428571429, 0.036716621428571426, 0.03817613917525773, 0.03948561122448979, 0.04065963979591837, 0.04193762142857143, 0.043113498979591845, 0.044032394845360825, 0.04495883265306123, 0.046144063265306116, 0.04736851428571429, 0.04873776288659794, 0.04996497755102042, 0.051019404081632656, 0.05214295612244898, 0.05321978367346939, 0.05415648775510204, 0.05502652142857143, 0.0559053051020408, 0.0569310775510204, 0.05803083814432989, 0.05903430612244898, 0.05998721326530613, 0.060813702040816306, 0.06168915979381443, 0.06265492244897959, 0.06322915816326531, 0.06411104999999999, 0.06495371938775509, 0.06583871734693876, 0.06645968163265305, 0.06727118571428573, 0.06805344183673472, 0.06890918969072164, 0.0699692020408163, 0.07099995, 0.07204066734693879, 0.07306336701030927, 0.07413018367346938, 0.07518458979591838, 0.07638101326530612, 0.07765400306122448, 0.0792102556701031, 0.0807213581632653, 0.08219861632653062, 0.08369462857142859, 0.08539622989690719, 0.08696251530612249, 0.08876177346938773, 0.0905510693877551, 0.09230120612244898, 0.09428846701030928, 0.09650205306122446, 0.0991919214285714, 0.10221904693877551, 0.10563367999999995, 0.10932373999999999, 0.11329965999999997, 0.11766926999999998, 0.12256984158415839, 0.127937, 0.13443840999999998, 0.14191919417475732, 0.15091103846153847, 0.16137559615384617, 0.1734388846153846, 0.1876206, 0.2053153523809524, 0.2297385192307692, 0.3172010194174758, 0.44423633009708746, 0.44271722330097096, 0.45632424509803915, 0.47687266990291255, 0.4769996990291263, 0.46876981553398056, 0.4537566407766991, 0.4366127475728155, 0.4188434563106796, 0.3992503535353536, 0.37781180808080805, 0.35625980808080804, 0.33368729292929294, 0.3146929494949495, 0.2971993131313131, 0.2791608888888889, 0.2616869292929293, 0.2445480808080808, 0.22899273737373738, 0.21544337373737368, 0.20349083838383836, 0.19283324242424235, 0.18339025252525254, 0.17505313131313127, 0.1673960202020202, 0.16048915151515153, 0.154232101010101, 0.14857292929292928, 0.14329503030303034, 0.13862681818181818, 0.13428425510204087, 0.1305238979591837, 0.12703618367346942, 0.1238724639175258, 0.12116995918367345, 0.11883538775510201, 0.1168867448979592, 0.11512621649484538, 0.11369095918367349, 0.11240895918367347, 0.11117769387755104, 0.11006008163265307, 0.10903390816326528, 0.10815188775510201, 0.10724398979591837, 0.10635761224489791, 0.10552067346938773, 0.10480127956989246, 0.10417850537634407, 0.10367473118279567, 0.10332775268817206, 0.10309555913978496, 0.10291059139784947, 0.10281810752688172, 0.10278268817204299, 0.10282991397849464, 0.10295388172043016, 0.10296109677419354, 0.1030680107526882, 0.10314016129032254, 0.10320640860215051, 0.10315065591397846, 0.10315918279569891, 0.10321165591397846, 0.1032779032258065, 0.10344975268817204, 0.10382362365591398, 0.1042097311827957, 0.10464779569892478, 0.105025193877551, 0.10550136734693877, 0.10600778571428572, 0.1064472448979592, 0.10694594845360825, 0.10740768367346937, 0.10790289795918366, 0.10844755102040815, 0.10901584693877552, 0.1097948979591837, 0.11059102040816327, 0.11151883673469387, 0.11253956701030926, 0.11354030612244899, 0.11468350000000004, 0.11588545918367348, 0.1169035306122449, 0.11786024489795917, 0.1185844432989691, 0.11910987755102043, 0.11940367346938772, 0.11940072164948454, 0.11903020408163266, 0.11842207142857143, 0.11762123469387754, 0.116456, 0.11511736734693877, 0.11372503 ...

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np


with open('../../data/kagome-01.21.2022-corner/raw/gamma-K-2/scppos_12_12.pkl', 'rb') as f:
    data = pickle.load(f)

with open('../../data/kagome-01.15.2022-1transducer/noMetamaterial3.pkl', 'rb') as f:
    ref = pickle.load(f)


freq = data[:,0]
amplitude = data[:,1]
phase = data[:,2]


normFactor = ref[:,1]



plt.figure(figsize=(20,10))
plt.plot(freq/1000, amplitude, 'b-')
#plt.axis([0, 20, 0, 0.2])
plt.xlabel("frequency (kHz)")
plt.ylabel("response amplitude (V)")
plt.xticks(np.linspace(0, 20, 21))
plt.grid()
plt.savefig("../../data/kagome-01.21.2022-corner/response/12_12_amp.png")

plt.figure(figsize=(20,10))
plt.plot(freq/1000, amplitude/normFactor, 'b-')
plt.axis([4, 20, 0, max(amplitude/normFactor)])
plt.xlabel("frequency (kHz)")
plt.ylabel("response amplitude (V)")
plt.xticks(np.linspace(0, 20, 21))
plt.grid()


plt.figure()
plt.plot(freq, phase, 'b-')
#plt.axis([0, 20000, 0, 0.25])
plt.xlabel("frequency (Hz)")
plt.ylabel("response amplitude (V)")
plt.grid()
'''
plt.savefig("../../data/kagome-01.21.2022-corner/response/2_2_phase.png")
'''
# Out:
# '\nplt.savefig("../../data/kagome-01.21.2022-corner/response/2_2_phase.png")\n'

# %%
a = np.linspace(1000,20000,951)
a
# Out:
# array([ 1000.,  1020.,  1040.,  1060.,  1080.,  1100.,  1120.,  1140.,
#         1160.,  1180.,  1200.,  1220.,  1240.,  1260.,  1280.,  1300.,
#         1320.,  1340.,  1360.,  1380.,  1400.,  1420.,  1440.,  1460.,
#         1480.,  1500.,  1520.,  1540.,  1560.,  1580.,  1600.,  1620.,
#         1640.,  1660.,  1680.,  1700.,  1720.,  1740.,  1760.,  1780.,
#         1800.,  1820.,  1840.,  1860.,  1880.,  1900.,  1920.,  1940.,
#         1960.,  1980.,  2000.,  2020.,  2040.,  2060.,  2080.,  2100.,
#         2120.,  2140.,  2160.,  2180.,  2200.,  2220.,  2240.,  2260.,
#         2280.,  2300.,  2320.,  2340.,  2360.,  2380.,  2400.,  2420.,
#         2440.,  2460.,  2480.,  2500.,  2520.,  2540.,  2560.,  2580.,
#         2600.,  2620.,  2640.,  2660.,  2680.,  2700.,  2720.,  2740.,
#         2760.,  2780.,  2800.,  2820.,  2840.,  2860.,  2880.,  2900.,
#         2920.,  2940.,  2960.,  2980.,  3000.,  3020.,  3040.,  3060.,
#         3080.,  3100.,  3120.,  3140.,  3160.,  3180.,  3200.,  3220.,
#         3240.,  3260.,  3280.,  3300.,  3320.,  3340.,  3360.,  3380.,
#         3400.,  3420.,  3440.,  3460.,  3480.,  3500.,  3520.,  3540.,
#         3560.,  3580.,  3600.,  3620.,  3640.,  3660.,  3680.,  3700.,
#         3720.,  3740.,  3760.,  3780.,  3800.,  3820.,  3840.,  3860.,
#         3880.,  3900.,  3920.,  3940.,  3960.,  3980.,  4000.,  4020.,
#         4040.,  4060.,  4080.,  4100.,  4120.,  4140.,  4160.,  4180.,
#         4200.,  4220.,  4240.,  4260.,  4280.,  4300.,  4320.,  4340.,
#         4360.,  4380.,  4400.,  4420.,  4440.,  4460.,  4480.,  4500.,
#         4520.,  4540.,  4560.,  4580.,  4600.,  4620.,  4640.,  4660.,
#         4680.,  4700.,  4720.,  4740.,  4760.,  4780.,  4800.,  4820.,
#         4840.,  4860.,  4880.,  4900.,  4920.,  4940.,  4960.,  4980.,
#         5000.,  5020.,  5040.,  5060.,  5080.,  5100.,  5120.,  5140.,
#         5160.,  5180.,  5200.,  5220.,  5240.,  5260.,  5280.,  5300.,
#         5320.,  5340.,  5360.,  5380.,  5400.,  5420.,  5440.,  5460.,
#         5480.,  5500.,  5520.,  5540.,  5560.,  5580.,  5600.,  5620.,
#         5640.,  5660.,  5680.,  5700.,  5720.,  5740.,  5760.,  5780.,
#         5800.,  5820.,  5840.,  5860.,  5880.,  5900.,  5920.,  5940.,
#         5960.,  5980.,  6000.,  6020.,  6040.,  6060.,  6080.,  6100.,
#         6120.,  6140.,  6160.,  6180.,  6200.,  6220.,  6240.,  6260.,
#         6280.,  6300.,  6320.,  6340.,  6360.,  6380.,  6400.,  6420.,
#         6440.,  6460.,  6480.,  6500.,  6520.,  6540.,  6560.,  6580.,
#         6600.,  6620.,  6640.,  6660.,  6680.,  6700.,  6720.,  6740.,
#         6760.,  6780.,  6800.,  6820.,  6840.,  6860.,  6880.,  6900.,
#         6920.,  6940.,  6960.,  6980.,  7000.,  7020.,  7040.,  7060.,
#         7080.,  7100.,  7120.,  7140.,  7160.,  7180.,  7200.,  7220.,
#         7240.,  7260.,  7280.,  7300.,  7320.,  7340.,  7360.,  7380.,
#         7400.,  7420.,  7440.,  7460.,  7480.,  7500.,  7520.,  7540.,
#         7560.,  7580.,  7600.,  7620.,  7640.,  7660.,  7680.,  7700.,
#         7720.,  7740.,  7760.,  7780.,  7800.,  7820.,  7840.,  7860.,
#         7880.,  7900.,  7920.,  7940.,  7960.,  7980.,  8000.,  8020.,
#         8040.,  8060.,  8080.,  8100.,  8120.,  8140.,  8160.,  8180.,
#         8200.,  8220.,  8240.,  8260.,  8280.,  8300.,  8320.,  8340.,
#         8360.,  8380.,  8400.,  8420.,  8440.,  8460.,  8480.,  8500.,
#         8520.,  8540.,  8560.,  8580.,  8600.,  8620.,  8640.,  8660.,
#         8680.,  8700.,  8720.,  8740.,  8760.,  8780.,  8800.,  8820.,
#         8840.,  8860.,  8880.,  8900.,  8920.,  8940.,  8960.,  8980.,
#         9000.,  9020.,  9040.,  9060.,  9080.,  9100.,  9120.,  9140.,
#         9160.,  9180.,  9200.,  9220.,  9240.,  9260.,  9280.,  9300.,
#         9320.,  9340.,  9360.,  9380.,  9400.,  9420.,  9440.,  9460.,
#         9480.,  9500.,  9520.,  9540.,  9560.,  9580.,  9600.,  9620.,
#         9640.,  9660.,  9680.,  9700.,  9720.,  9740.,  9760.,  9780.,
#         9800.,  9820.,  9840.,  9860.,  9880.,  9900.,  9920.,  9940.,
#         9960.,  9980., 10000., 10020., 10040., 10060., 10080., 10100.,
#        10120., 10140., 10160., 10180., 10200., 10220., 10240., 10260.,
#        10280., 10300., 10320., 10340., 10360., 10380., 10400., 10420.,
#        10440., 10460., 10480., 10500., 10520., 10540., 10560., 10580.,
#        10600., 10620., 10640., 10660., 10680., 10700., 10720., 10740.,
#        10760., 10780., 10800., 10820., 10840., 10860., 10880., 10900.,
#        10920., 10940., 10960., 10980., 11000., 11020., 11040., 11060.,
#        11080., 11100., 11120., 11140., 11160., 11180., 11200., 11220.,
#        11240., 11260., 11280., 11300., 11320., 11340., 11360., 11380.,
#        11400., 11420., 11440., 11460., 11480., 11500., 11520., 11540.,
#        11560., 11580., 11600., 11620., 11640., 11660., 11680., 11700.,
#        11720., 11740., 11760., 11780., 11800., 11820., 11840., 11860.,
#        11880., 11900., 11920., 11940., 11960., 11980., 12000., 12020.,
#        12040., 12060., 12080., 12100., 12120., 12140., 12160., 12180.,
#        12200., 12220., 12240., 12260., 12280., 12300., 12320., 12340.,
#        12360., 12380., 12400., 12420., 12440., 12460., 12480., 12500.,
#        12520., 12540., 12560., 12580., 12600., 12620., 12640., 12660.,
#        12680., 12700., 12720., 12740., 12760., 12780., 12800., 12820.,
#        12840., 12860., 12880., 12900., 12920., 12940., 12960., 12980.,
#        13000., 13020., 13040., 13060., 13080., 13100., 13120., 13140.,
#        13160., 13180., 13200., 13220., 13240., 13260., 13280., 13300.,
#        13320., 13340., 13360., 13380., 13400., 13420., 13440., 13460.,
#        13480., 13500., 13520., 13540., 13560., 13580., 13600., 13620.,
#        13640., 13660., 13680., 13700., 13720., 13740., 13760., 13780.,
#        13800., 13820., 13840., 13860., 13880., 13900., 13920., 13940.,
#        13960., 13980., 14000., 14020., 14040., 14060., 14080., 14100.,
#        14120., 14140., 14160., 14180., 14200., 14220., 14240., 14260.,
#        14280., 14300., 14320., 14340., 14360., 14380., 14400., 14420.,
#        14440., 14460., 14480., 14500., 14520., 14540., 14560., 14580.,
#        14600., 14620., 14640., 14660., 14680., 14700., 14720., 14740.,
#        14760., 14780., 14800., 14820., 14840., 14860., 14880., 14900.,
#        14920., 14940., 14960., 14980., 15000., 15020., 15040., 15060.,
#        15080., 15100., 15120., 15140., 15160., 15180., 15200., 15220.,
#        15240., 15260., 15280., 15300., 15320., 15340., 15360., 15380.,
#        15400., 15420., 15440., 15460., 15480., 15500., 15520., 15540.,
#        15560., 15580., 15600., 15620., 15640., 15660., 15680., 15700.,
#        15720., 15740., 15760., 15780., 15800., 15820., 15840., 15860.,
#        15880., 15900., 15920., 15940., 15960., 15980., 16000., 16020.,
#        16040., 16060., 16080., 16100., 16120., 16140., 16160., 16180.,
#        16200., 16220., 16240., 16260., 16280., 16300., 16320., 16340.,
#        16360., 16380., 16400., 16420., 16440., 16460., 16480., 16500.,
#        16520., 16540., 16560., 16580., 16600., 16620., 16640., 16660.,
#        16680., 16700., 16720., 16740., 16760., 16780., 16800., 16820.,
#        16840., 16860., 16880., 16900., 16920., 16940., 16960., 16980.,
#        17000., 17020., 17040., 17060., 17080., 17100., 17120., 17140.,
#        17160., 17180., 17200., 17220., 17240., 17260., 17280., 17300.,
#        17320., 17340., 17360., 17380., 17400., 17420., 17440., 17460.,
#        17480., 17500., 17520., 17540., 17560., 17580., 17600., 17620.,
#        17640., 17660., 17680., 17700., 17720., 17740., 17760., 17780.,
#        17800., 17820., 17840., 17860., 17880., 17900., 17920., 17940.,
#        17960., 17980., 18000., 18020., 18040., 18060., 18080., 18100.,
#        18120., 18140., 18160., 18180., 18200., 18220., 18240., 18260.,
#        18280., 18300., 18320., 18340., 18360., 18380., 18400., 18420.,
#        18440., 18460., 18480., 18500., 18520., 18540., 18560., 18580.,
#        18600., 18620., 18640., 18660., 18680., 18700., 18720., 18740.,
#        18760., 18780., 18800., 18820., 18840., 18860., 18880., 18900.,
#        18920., 18940., 18960., 18980., 19000., 19020., 19040., 19060.,
#        19080., 19100., 19120., 19140., 19160., 19180., 19200., 19220.,
#        19240., 19260., 19280., 19300., 19320., 19340., 19360., 19380.,
#        19400., 19420., 19440., 19460., 19480., 19500., 19520., 19540.,
#        19560., 19580., 19600., 19620., 19640., 19660., 19680., 19700.,
#        19720., 19740., 19760., 19780., 19800., 19820., 19840., 19860.,
#        19880., 19900., 19920., 19940., 19960., 19980., 20000.])
